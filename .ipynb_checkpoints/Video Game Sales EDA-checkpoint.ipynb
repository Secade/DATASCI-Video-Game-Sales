# %% [markdown]
# ## Research Questions
# - What genre of games have the highest sales? (Jeff)
# - What kind of ESRB ratings do top selling games have? (Kristen)
# - Which publishers have received the most sales? (Kyle)
# - What are the sales trends of certain games in different regions? (Jeff)
# - Do certain regions lean towards specific game genres? (Kristen)
# - On what platform do games receive more sales? (Kyle)
# - What is the relationship between the critic & user scores to the game’s sales? (Jeff)
# - Are newer games able to compare against older games with sales? (Kristen)
# - What is the trend of newer video game releases per console? (Kyle)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import zscore
import datetime as dt

# %%
df2019 = pd.read_csv('vgsales-12-4-2019.csv')
df2020 = pd.read_csv('vgchartz-7_7_2020.csv')

# %%
df2019
# Out:
#         Rank                           Name                      basename  \
# 0          1                     Wii Sports                    wii-sports
# 1          2              Super Mario Bros.              super-mario-bros
# 2          3                 Mario Kart Wii                mario-kart-wii
# 3          4  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4          5              Wii Sports Resort             wii-sports-resort
# ...      ...                            ...                           ...
# 55787  55788                    Indivisible                   indivisible
# 55788  55789                     Lost Ember                    lost-amber
# 55789  55790                     Lost Ember                    lost-amber
# 55790  55791                     Lost Ember                    lost-amber
# 55791  55792                     Falcon Age                    falcon-age
#
#                   Genre ESRB_Rating Platform         Publisher  \
# 0                Sports           E      Wii          Nintendo
# 1              Platform         NaN      NES          Nintendo
# 2                Racing           E      Wii          Nintendo
# 3               Shooter         NaN       PC  PUBG Corporation
# 4                Sports           E      Wii          Nintendo
# ...                 ...         ...      ...               ...
# 55787      Role-Playing         NaN       PC         505 Games
# 55788         Adventure          RP       PC   Mooneye Studios
# 55789         Adventure          RP      PS4   Mooneye Studios
# 55790         Adventure          RP     XOne   Mooneye Studios
# 55791  Action-Adventure         NaN      PS4           Unknown
#
#               Developer  VGChartz_Score  Critic_Score  ...  NA_Sales  \
# 0          Nintendo EAD             NaN           7.7  ...       NaN
# 1          Nintendo EAD             NaN          10.0  ...       NaN
# 2          Nintendo EAD             NaN           8.2  ...       NaN
# 3      PUBG Corporation             NaN           NaN  ...       NaN
# 4          Nintendo EAD             NaN           8.0  ...       NaN
# ...                 ...             ...           ...  ...       ...
# 55787    Lab Zero Games             NaN           NaN  ...       NaN
# 55788   Mooneye Studios             NaN           NaN  ...       NaN
# 55789   Mooneye Studios             NaN           NaN  ...       NaN
# 55790   Mooneye Studios             NaN           NaN  ...       NaN
# 55791   Outerloop Games             NaN           NaN  ...       NaN
#
#        PAL_Sales  JP_Sales  Other_Sales    Year  Last_Update  \
# 0            NaN       NaN          NaN  2006.0          NaN
# 1            NaN       NaN          NaN  1985.0          NaN
# 2            NaN       NaN          NaN  2008.0  11th Apr 18
# 3            NaN       NaN          NaN  2017.0  13th Nov 18
# 4            NaN       NaN          NaN  2009.0          NaN
# ...          ...       ...          ...     ...          ...
# 55787        NaN       NaN          NaN  2019.0  11th Apr 19
# 55788        NaN       NaN          NaN  2019.0  11th Apr 19
# 55789        NaN       NaN          NaN  2019.0  11th Apr 19
# 55790        NaN       NaN          NaN  2019.0  11th Apr 19
# 55791        NaN       NaN          NaN     NaN  12th Apr 19
#
#                                                      url  status  \
# 0      http://www.vgchartz.com/game/2667/wii-sports/?...       1
# 1      http://www.vgchartz.com/game/6455/super-mario-...       1
# 2      http://www.vgchartz.com/game/6968/mario-kart-w...       1
# 3      http://www.vgchartz.com/game/215988/playerunkn...       1
# 4      http://www.vgchartz.com/game/24656/wii-sports-...       1
# ...                                                  ...     ...
# 55787  http://www.vgchartz.com/game/224682/indivisibl...       1
# 55788  http://www.vgchartz.com/games/game.php?id=2246...       1
# 55789  http://www.vgchartz.com/game/224690/lost-ember...       1
# 55790  http://www.vgchartz.com/game/224688/lost-ember...       1
# 55791  http://www.vgchartz.com/game/224692/falcon-age...       1
#
#       Vgchartzscore                                        img_url
# 0               NaN  /games/boxart/full_2258645AmericaFrontccc.jpg
# 1               NaN                   /games/boxart/8972270ccc.jpg
# 2               8.7  /games/boxart/full_8932480AmericaFrontccc.jpg
# 3               NaN  /games/boxart/full_8052843AmericaFrontccc.jpg
# 4               8.8  /games/boxart/full_7295041AmericaFrontccc.jpg
# ...             ...                                            ...
# 55787           NaN  /games/boxart/full_6339426AmericaFrontccc.jpg
# 55788           NaN  /games/boxart/full_8893129AmericaFrontccc.jpg
# 55789           NaN  /games/boxart/full_6514293AmericaFrontccc.jpg
# 55790           NaN  /games/boxart/full_6799693AmericaFrontccc.jpg
# 55791           NaN                      /games/boxart/default.jpg
#
# [55792 rows x 23 columns]

# %%
df2020
# Out:
#        Unnamed: 0                                            img  \
# 0               3  /games/boxart/full_3351915AmericaFrontccc.jpg
# 1               4  /games/boxart/full_5741036AmericaFrontccc.jpg
# 2               5  /games/boxart/full_6662824AmericaFrontccc.png
# 3               6  /games/boxart/full_6510540AmericaFrontccc.jpg
# 4               7  /games/boxart/full_6800951AmericaFrontccc.jpg
# ...           ...                                            ...
# 57945       58851    /games/boxart/full_2294305JapanFrontccc.jpg
# 57946       58852  /games/boxart/full_2779838AmericaFrontccc.jpg
# 57947       58853  /games/boxart/full_6553045AmericaFrontccc.jpg
# 57948       58854  /games/boxart/full_8031506AmericaFrontccc.jpg
# 57949       58855    /games/boxart/full_6012940JapanFrontccc.png
#
#                                  title console         genre  \
# 0                             Warriors  Series        Action
# 1                           God of War  Series        Action
# 2                        Devil May Cry  Series        Action
# 3                   Grand Theft Auto V     PS3        Action
# 4                              Frogger  Series        Action
# ...                                ...     ...           ...
# 57945               World End Syndrome     PS4  Visual Novel
# 57946            XBlaze Lost: Memories      PC  Visual Novel
# 57947                     Yoru, Tomosu      NS  Visual Novel
# 57948                     Yoru, Tomosu     PS4  Visual Novel
# 57949  Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
#
#                          publisher  \
# 0                          Unknown
# 1      Sony Computer Entertainment
# 2                           Capcom
# 3                   Rockstar Games
# 4                           Konami
# ...                            ...
# 57945             Arc System Works
# 57946                  Aksys Games
# 57947         Nippon Ichi Software
# 57948         Nippon Ichi Software
# 57949                 Idea Factory
#
#                                                developer  vg_score  \
# 0                                            Omega Force       NaN
# 1      SIE Santa Monica Studio|Ready at Dawn|Javagrou...       NaN
# 2                                    Capcom|Ninja Theory       NaN
# 3                                         Rockstar North       NaN
# 4      Konami|Parker Brothers|SCE Cambridge Studio|Bl...       NaN
# ...                                                  ...       ...
# 57945                                   Arc System Works       NaN
# 57946                                   Arc System Works       NaN
# 57947                               Nippon Ichi Software       NaN
# 57948                               Nippon Ichi Software       NaN
# 57949                                            Otomate       NaN
#
#        critic_score  user_score  total_shipped  total_sales  na_sales  \
# 0               NaN         NaN          42.06          NaN       NaN
# 1               NaN         NaN          35.05          NaN       NaN
# 2               NaN         NaN          22.00          NaN       NaN
# 3               9.4         NaN            NaN        20.32      6.37
# 4               NaN         NaN          20.00          NaN       NaN
# ...             ...         ...            ...          ...       ...
# 57945           NaN         NaN            NaN          NaN       NaN
# 57946           NaN         NaN            NaN          NaN       NaN
# 57947           NaN         NaN            NaN          NaN       NaN
# 57948           NaN         NaN            NaN          NaN       NaN
# 57949           NaN         NaN            NaN          NaN       NaN
#
#        jp_sales  pal_sales  other_sales release_date last_update
# 0           NaN        NaN          NaN          NaN  2020-03-24
# 1           NaN        NaN          NaN   2005-03-22  2020-03-04
# 2           NaN        NaN          NaN   2001-10-16  2020-02-03
# 3          0.99       9.85         3.12   2013-09-17         NaN
# 4           NaN        NaN          NaN   1981-10-23  2020-02-26
# ...         ...        ...          ...          ...         ...
# 57945       NaN        NaN          NaN   2018-04-26  2019-04-03
# 57946       NaN        NaN          NaN   2016-08-11  2019-01-28
# 57947       NaN        NaN          NaN   2020-07-30  2020-05-09
# 57948       NaN        NaN          NaN   2020-07-30  2020-05-09
# 57949       NaN        NaN          NaN   2019-02-28  2019-02-24
#
# [57950 rows x 18 columns]

# %%
df2019.rename({'Name': 'title'}, axis=1, inplace=True)
df2019=df2019[['title','ESRB_Rating']]
df2020.rename({'total_sales': 'global_sales'}, axis=1, inplace=True)
df2019
# Out:
#                                title ESRB_Rating
# 0                         Wii Sports           E
# 1                  Super Mario Bros.         NaN
# 2                     Mario Kart Wii           E
# 3      PlayerUnknown's Battlegrounds         NaN
# 4                  Wii Sports Resort           E
# ...                              ...         ...
# 55787                    Indivisible         NaN
# 55788                     Lost Ember          RP
# 55789                     Lost Ember          RP
# 55790                     Lost Ember          RP
# 55791                     Falcon Age         NaN
#
# [55792 rows x 2 columns]

# %%
df_merged = pd.merge(df2020, df2019,how="inner")
#df_merged = df2020.join(df2019,how="inner",on="title")
#df_merged = pd.concat(df2020, df2019,how="left")
#df_merged = pd.concat([df2020, df2019], axis=1)
#df_merged = pd.merge(df2020, df2019, left_index=True, right_index=True, how='outer')
df_merged
# Out:
#         Unnamed: 0                                            img  \
# 0                4  /games/boxart/full_5741036AmericaFrontccc.jpg
# 1               50  /games/boxart/full_5633331AmericaFrontccc.jpg
# 2                5  /games/boxart/full_6662824AmericaFrontccc.png
# 3              144  /games/boxart/full_8688619AmericaFrontccc.jpg
# 4             7454  /games/boxart/full_7401032AmericaFrontccc.jpg
# ...            ...                                            ...
# 130024       58846  /games/boxart/full_7024289AmericaFrontccc.jpg
# 130025       58847                      /games/boxart/default.jpg
# 130026       58848                      /games/boxart/default.jpg
# 130027       58849                      /games/boxart/default.jpg
# 130028       58855    /games/boxart/full_6012940JapanFrontccc.png
#
#                                   title console         genre  \
# 0                            God of War  Series        Action
# 1                            God of War     PS2        Action
# 2                         Devil May Cry  Series        Action
# 3                         Devil May Cry     PS2        Action
# 4                         Devil May Cry      NS        Action
# ...                                 ...     ...           ...
# 130024          WILL: A Wonderful World      PC  Visual Novel
# 130025                   Without Within      PC  Visual Novel
# 130026                 Without Within 2      PC  Visual Novel
# 130027                 Without Within 3      PC  Visual Novel
# 130028  Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
#
#                           publisher  \
# 0       Sony Computer Entertainment
# 1       Sony Computer Entertainment
# 2                            Capcom
# 3                            Capcom
# 4                            Capcom
# ...                             ...
# 130024                  AGM Playism
# 130025                  InvertMouse
# 130026                  InvertMouse
# 130027                  InvertMouse
# 130028                 Idea Factory
#
#                                                 developer  vg_score  \
# 0       SIE Santa Monica Studio|Ready at Dawn|Javagrou...       NaN
# 1                                SCEA Santa Monica Studio       NaN
# 2                                     Capcom|Ninja Theory       NaN
# 3                                                  Capcom       NaN
# 4                                                  Capcom       NaN
# ...                                                   ...       ...
# 130024                                      4D Door Games       NaN
# 130025                                        InvertMouse       NaN
# 130026                                        InvertMouse       NaN
# 130027                                        InvertMouse       NaN
# 130028                                            Otomate       NaN
#
#         critic_score  user_score  total_shipped  global_sales  na_sales  \
# 0                NaN         NaN          35.05           NaN       NaN
# 1                9.3         NaN           4.62           NaN       NaN
# 2                NaN         NaN          22.00           NaN       NaN
# 3                9.1         9.3           2.16           NaN       NaN
# 4                NaN         NaN            NaN           NaN       NaN
# ...              ...         ...            ...           ...       ...
# 130024           NaN         NaN            NaN           NaN       NaN
# 130025           NaN         NaN            NaN           NaN       NaN
# 130026           NaN         NaN            NaN           NaN       NaN
# 130027           NaN         NaN            NaN           NaN       NaN
# 130028           NaN         NaN            NaN           NaN       NaN
#
#         jp_sales  pal_sales  other_sales release_date last_update ESRB_Rating
# 0            NaN        NaN          NaN   2005-03-22  2020-03-04           M
# 1            NaN        NaN          NaN   2005-03-22         NaN           M
# 2            NaN        NaN          NaN   2001-10-16  2020-02-03           M
# 3            NaN        NaN          NaN   2001-10-16         NaN           M
# 4            NaN        NaN          NaN   2019-10-01  2019-05-06           M
# ...          ...        ...          ...          ...         ...         ...
# 130024       NaN        NaN          NaN   2017-06-06  2018-12-17         NaN
# 130025       NaN        NaN          NaN   2015-01-22  2018-12-25         NaN
# 130026       NaN        NaN          NaN   2015-11-09  2018-12-25         NaN
# 130027       NaN        NaN          NaN   2018-05-03  2018-12-25         NaN
# 130028       NaN        NaN          NaN   2019-02-28  2019-02-24         NaN
#
# [130029 rows x 19 columns]

# %%
df_merged.drop_duplicates(keep='first',inplace=True,subset=df_merged.columns.difference(['title','console','ESRB_Rating','genre','publisher','developer']))
df_merged
# Out:
#         Unnamed: 0                                            img  \
# 0                4  /games/boxart/full_5741036AmericaFrontccc.jpg
# 1               50  /games/boxart/full_5633331AmericaFrontccc.jpg
# 2                5  /games/boxart/full_6662824AmericaFrontccc.png
# 3              144  /games/boxart/full_8688619AmericaFrontccc.jpg
# 4             7454  /games/boxart/full_7401032AmericaFrontccc.jpg
# ...            ...                                            ...
# 130022       58846  /games/boxart/full_7024289AmericaFrontccc.jpg
# 130025       58847                      /games/boxart/default.jpg
# 130026       58848                      /games/boxart/default.jpg
# 130027       58849                      /games/boxart/default.jpg
# 130028       58855    /games/boxart/full_6012940JapanFrontccc.png
#
#                                   title console         genre  \
# 0                            God of War  Series        Action
# 1                            God of War     PS2        Action
# 2                         Devil May Cry  Series        Action
# 3                         Devil May Cry     PS2        Action
# 4                         Devil May Cry      NS        Action
# ...                                 ...     ...           ...
# 130022          WILL: A Wonderful World      PC  Visual Novel
# 130025                   Without Within      PC  Visual Novel
# 130026                 Without Within 2      PC  Visual Novel
# 130027                 Without Within 3      PC  Visual Novel
# 130028  Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
#
#                           publisher  \
# 0       Sony Computer Entertainment
# 1       Sony Computer Entertainment
# 2                            Capcom
# 3                            Capcom
# 4                            Capcom
# ...                             ...
# 130022                  AGM Playism
# 130025                  InvertMouse
# 130026                  InvertMouse
# 130027                  InvertMouse
# 130028                 Idea Factory
#
#                                                 developer  vg_score  \
# 0       SIE Santa Monica Studio|Ready at Dawn|Javagrou...       NaN
# 1                                SCEA Santa Monica Studio       NaN
# 2                                     Capcom|Ninja Theory       NaN
# 3                                                  Capcom       NaN
# 4                                                  Capcom       NaN
# ...                                                   ...       ...
# 130022                                      4D Door Games       NaN
# 130025                                        InvertMouse       NaN
# 130026                                        InvertMouse       NaN
# 130027                                        InvertMouse       NaN
# 130028                                            Otomate       NaN
#
#         critic_score  user_score  total_shipped  global_sales  na_sales  \
# 0                NaN         NaN          35.05           NaN       NaN
# 1                9.3         NaN           4.62           NaN       NaN
# 2                NaN         NaN          22.00           NaN       NaN
# 3                9.1         9.3           2.16           NaN       NaN
# 4                NaN         NaN            NaN           NaN       NaN
# ...              ...         ...            ...           ...       ...
# 130022           NaN         NaN            NaN           NaN       NaN
# 130025           NaN         NaN            NaN           NaN       NaN
# 130026           NaN         NaN            NaN           NaN       NaN
# 130027           NaN         NaN            NaN           NaN       NaN
# 130028           NaN         NaN            NaN           NaN       NaN
#
#         jp_sales  pal_sales  other_sales release_date last_update ESRB_Rating
# 0            NaN        NaN          NaN   2005-03-22  2020-03-04           M
# 1            NaN        NaN          NaN   2005-03-22         NaN           M
# 2            NaN        NaN          NaN   2001-10-16  2020-02-03           M
# 3            NaN        NaN          NaN   2001-10-16         NaN           M
# 4            NaN        NaN          NaN   2019-10-01  2019-05-06           M
# ...          ...        ...          ...          ...         ...         ...
# 130022       NaN        NaN          NaN   2017-06-06  2018-12-17         NaN
# 130025       NaN        NaN          NaN   2015-01-22  2018-12-25         NaN
# 130026       NaN        NaN          NaN   2015-11-09  2018-12-25         NaN
# 130027       NaN        NaN          NaN   2018-05-03  2018-12-25         NaN
# 130028       NaN        NaN          NaN   2019-02-28  2019-02-24         NaN
#
# [55862 rows x 19 columns]

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55862 entries, 0 to 130028
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     55862 non-null  int64
#  1   img            55862 non-null  object
#  2   title          55862 non-null  object
#  3   console        55862 non-null  object
#  4   genre          55862 non-null  object
#  5   publisher      55862 non-null  object
#  6   developer      55845 non-null  object
#  7   vg_score       853 non-null    float64
#  8   critic_score   6492 non-null   float64
#  9   user_score     375 non-null    float64
#  10  total_shipped  2209 non-null   float64
#  11  global_sales   19193 non-null  float64
#  12  na_sales       12872 non-null  float64
#  13  jp_sales       6901 non-null   float64
#  14  pal_sales      13065 non-null  float64
#  15  other_sales    15382 non-null  float64
#  16  release_date   52701 non-null  object
#  17  last_update    9865 non-null   object
#  18  ESRB_Rating    24685 non-null  object
# dtypes: float64(9), int64(1), object(9)
# memory usage: 8.5+ MB

# %%
df_merged.isnull().sum()
# Out:
# Unnamed: 0           0
# img                  0
# title                0
# console              0
# genre                0
# publisher            0
# developer           17
# vg_score         55009
# critic_score     49370
# user_score       55487
# total_shipped    53653
# global_sales     36669
# na_sales         42990
# jp_sales         48961
# pal_sales        42797
# other_sales      40480
# release_date      3161
# last_update      45997
# ESRB_Rating      31177
# dtype: int64

# %%
df_merged.dropna(subset=['developer'],inplace=True)
df_merged = df_merged.reset_index(drop=True)
df_merged
# Out:
#        Unnamed: 0                                            img  \
# 0               4  /games/boxart/full_5741036AmericaFrontccc.jpg
# 1              50  /games/boxart/full_5633331AmericaFrontccc.jpg
# 2               5  /games/boxart/full_6662824AmericaFrontccc.png
# 3             144  /games/boxart/full_8688619AmericaFrontccc.jpg
# 4            7454  /games/boxart/full_7401032AmericaFrontccc.jpg
# ...           ...                                            ...
# 55840       58846  /games/boxart/full_7024289AmericaFrontccc.jpg
# 55841       58847                      /games/boxart/default.jpg
# 55842       58848                      /games/boxart/default.jpg
# 55843       58849                      /games/boxart/default.jpg
# 55844       58855    /games/boxart/full_6012940JapanFrontccc.png
#
#                                  title console         genre  \
# 0                           God of War  Series        Action
# 1                           God of War     PS2        Action
# 2                        Devil May Cry  Series        Action
# 3                        Devil May Cry     PS2        Action
# 4                        Devil May Cry      NS        Action
# ...                                ...     ...           ...
# 55840          WILL: A Wonderful World      PC  Visual Novel
# 55841                   Without Within      PC  Visual Novel
# 55842                 Without Within 2      PC  Visual Novel
# 55843                 Without Within 3      PC  Visual Novel
# 55844  Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
#
#                          publisher  \
# 0      Sony Computer Entertainment
# 1      Sony Computer Entertainment
# 2                           Capcom
# 3                           Capcom
# 4                           Capcom
# ...                            ...
# 55840                  AGM Playism
# 55841                  InvertMouse
# 55842                  InvertMouse
# 55843                  InvertMouse
# 55844                 Idea Factory
#
#                                                developer  vg_score  \
# 0      SIE Santa Monica Studio|Ready at Dawn|Javagrou...       NaN
# 1                               SCEA Santa Monica Studio       NaN
# 2                                    Capcom|Ninja Theory       NaN
# 3                                                 Capcom       NaN
# 4                                                 Capcom       NaN
# ...                                                  ...       ...
# 55840                                      4D Door Games       NaN
# 55841                                        InvertMouse       NaN
# 55842                                        InvertMouse       NaN
# 55843                                        InvertMouse       NaN
# 55844                                            Otomate       NaN
#
#        critic_score  user_score  total_shipped  global_sales  na_sales  \
# 0               NaN         NaN          35.05           NaN       NaN
# 1               9.3         NaN           4.62           NaN       NaN
# 2               NaN         NaN          22.00           NaN       NaN
# 3               9.1         9.3           2.16           NaN       NaN
# 4               NaN         NaN            NaN           NaN       NaN
# ...             ...         ...            ...           ...       ...
# 55840           NaN         NaN            NaN           NaN       NaN
# 55841           NaN         NaN            NaN           NaN       NaN
# 55842           NaN         NaN            NaN           NaN       NaN
# 55843           NaN         NaN            NaN           NaN       NaN
# 55844           NaN         NaN            NaN           NaN       NaN
#
#        jp_sales  pal_sales  other_sales release_date last_update ESRB_Rating
# 0           NaN        NaN          NaN   2005-03-22  2020-03-04           M
# 1           NaN        NaN          NaN   2005-03-22         NaN           M
# 2           NaN        NaN          NaN   2001-10-16  2020-02-03           M
# 3           NaN        NaN          NaN   2001-10-16         NaN           M
# 4           NaN        NaN          NaN   2019-10-01  2019-05-06           M
# ...         ...        ...          ...          ...         ...         ...
# 55840       NaN        NaN          NaN   2017-06-06  2018-12-17         NaN
# 55841       NaN        NaN          NaN   2015-01-22  2018-12-25         NaN
# 55842       NaN        NaN          NaN   2015-11-09  2018-12-25         NaN
# 55843       NaN        NaN          NaN   2018-05-03  2018-12-25         NaN
# 55844       NaN        NaN          NaN   2019-02-28  2019-02-24         NaN
#
# [55845 rows x 19 columns]

# %%
df_merged.drop(['Unnamed: 0', 'img','last_update'], axis = 1, inplace=True)
df_merged
# Out:
#                                  title console         genre  \
# 0                           God of War  Series        Action
# 1                           God of War     PS2        Action
# 2                        Devil May Cry  Series        Action
# 3                        Devil May Cry     PS2        Action
# 4                        Devil May Cry      NS        Action
# ...                                ...     ...           ...
# 55840          WILL: A Wonderful World      PC  Visual Novel
# 55841                   Without Within      PC  Visual Novel
# 55842                 Without Within 2      PC  Visual Novel
# 55843                 Without Within 3      PC  Visual Novel
# 55844  Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
#
#                          publisher  \
# 0      Sony Computer Entertainment
# 1      Sony Computer Entertainment
# 2                           Capcom
# 3                           Capcom
# 4                           Capcom
# ...                            ...
# 55840                  AGM Playism
# 55841                  InvertMouse
# 55842                  InvertMouse
# 55843                  InvertMouse
# 55844                 Idea Factory
#
#                                                developer  vg_score  \
# 0      SIE Santa Monica Studio|Ready at Dawn|Javagrou...       NaN
# 1                               SCEA Santa Monica Studio       NaN
# 2                                    Capcom|Ninja Theory       NaN
# 3                                                 Capcom       NaN
# 4                                                 Capcom       NaN
# ...                                                  ...       ...
# 55840                                      4D Door Games       NaN
# 55841                                        InvertMouse       NaN
# 55842                                        InvertMouse       NaN
# 55843                                        InvertMouse       NaN
# 55844                                            Otomate       NaN
#
#        critic_score  user_score  total_shipped  global_sales  na_sales  \
# 0               NaN         NaN          35.05           NaN       NaN
# 1               9.3         NaN           4.62           NaN       NaN
# 2               NaN         NaN          22.00           NaN       NaN
# 3               9.1         9.3           2.16           NaN       NaN
# 4               NaN         NaN            NaN           NaN       NaN
# ...             ...         ...            ...           ...       ...
# 55840           NaN         NaN            NaN           NaN       NaN
# 55841           NaN         NaN            NaN           NaN       NaN
# 55842           NaN         NaN            NaN           NaN       NaN
# 55843           NaN         NaN            NaN           NaN       NaN
# 55844           NaN         NaN            NaN           NaN       NaN
#
#        jp_sales  pal_sales  other_sales release_date ESRB_Rating
# 0           NaN        NaN          NaN   2005-03-22           M
# 1           NaN        NaN          NaN   2005-03-22           M
# 2           NaN        NaN          NaN   2001-10-16           M
# 3           NaN        NaN          NaN   2001-10-16           M
# 4           NaN        NaN          NaN   2019-10-01           M
# ...         ...        ...          ...          ...         ...
# 55840       NaN        NaN          NaN   2017-06-06         NaN
# 55841       NaN        NaN          NaN   2015-01-22         NaN
# 55842       NaN        NaN          NaN   2015-11-09         NaN
# 55843       NaN        NaN          NaN   2018-05-03         NaN
# 55844       NaN        NaN          NaN   2019-02-28         NaN
#
# [55845 rows x 16 columns]

# %%
def addTotalSales(df_merged):
    if not pd.isna(df_merged['global_sales']):
        return df_merged['global_sales']
    elif not pd.isna(df_merged['total_shipped']):
        return df_merged['total_shipped']
    else:
        return df_merged['na_sales'] + df_merged['pal_sales'] + df_merged['jp_sales'] + df_merged['other_sales']

# %%
df_merged['Total_Sales'] = df_merged.apply(lambda x: addTotalSales(x), axis=1)

# %%
df_merged[0:20]
# Out:
#                  title console             genre                    publisher  \
# 0           God of War  Series            Action  Sony Computer Entertainment
# 1           God of War     PS2            Action  Sony Computer Entertainment
# 2        Devil May Cry  Series            Action                       Capcom
# 3        Devil May Cry     PS2            Action                       Capcom
# 4        Devil May Cry      NS            Action                       Capcom
# 5   Grand Theft Auto V     PS3            Action               Rockstar Games
# 6   Grand Theft Auto V     PS4            Action               Rockstar Games
# 7   Grand Theft Auto V    X360            Action               Rockstar Games
# 8   Grand Theft Auto V      PC            Action               Rockstar Games
# 9   Grand Theft Auto V    XOne            Action               Rockstar Games
# 10  Grand Theft Auto V     XSX  Action-Adventure               Rockstar Games
# 11  Grand Theft Auto V     PS5  Action-Adventure               Rockstar Games
# 12             Frogger  Series            Action                       Konami
# 13             Frogger      PS            Action           Hasbro Interactive
# 14             Frogger    2600            Action                 Parker Bros.
# 15             Frogger      GB            Action                      Majesco
# 16             Frogger    SNES            Action                      Majesco
# 17             Frogger     XBL            Action                       Konami
# 18             Frogger    5200            Action                 Parker Bros.
# 19             Frogger     GEN            Action                      Majesco
#
#                                             developer  vg_score  critic_score  \
# 0   SIE Santa Monica Studio|Ready at Dawn|Javagrou...       NaN           NaN
# 1                            SCEA Santa Monica Studio       NaN           9.3
# 2                                 Capcom|Ninja Theory       NaN           NaN
# 3                                              Capcom       NaN           9.1
# 4                                              Capcom       NaN           NaN
# 5                                      Rockstar North       NaN           9.4
# 6                                      Rockstar North       NaN           9.7
# 7                                      Rockstar North       NaN           NaN
# 8                                      Rockstar North       NaN           NaN
# 9                                      Rockstar North       NaN           9.0
# 10                                     Rockstar Games       NaN           NaN
# 11                                     Rockstar Games       NaN           NaN
# 12  Konami|Parker Brothers|SCE Cambridge Studio|Bl...       NaN           NaN
# 13                              Millenium Interactive       NaN           NaN
# 14                                             Konami       NaN           NaN
# 15                                      Majesco Games       NaN           NaN
# 16                            Morning Star Multimedia       NaN           NaN
# 17                                    Digital Eclipse       NaN           6.4
# 18                                    Parker Brothers       NaN           NaN
# 19                            Morning Star Multimedia       NaN           NaN
#
#     user_score  total_shipped  global_sales  na_sales  jp_sales  pal_sales  \
# 0          NaN          35.05           NaN       NaN       NaN        NaN
# 1          NaN           4.62           NaN       NaN       NaN        NaN
# 2          NaN          22.00           NaN       NaN       NaN        NaN
# 3          9.3           2.16           NaN       NaN       NaN        NaN
# 4          NaN            NaN           NaN       NaN       NaN        NaN
# 5          NaN            NaN         20.32      6.37      0.99       9.85
# 6          NaN            NaN         19.39      6.06      0.60       9.71
# 7          NaN            NaN         15.86      9.06      0.06       5.33
# 8          NaN          12.60           NaN       NaN       NaN        NaN
# 9          9.0            NaN          8.72      4.70      0.01       3.25
# 10         NaN            NaN           NaN       NaN       NaN        NaN
# 11         NaN            NaN           NaN       NaN       NaN        NaN
# 12         NaN          20.00           NaN       NaN       NaN        NaN
# 13         NaN            NaN          4.16      3.79       NaN       0.27
# 14         NaN            NaN          2.20      2.06       NaN       0.12
# 15         NaN            NaN           NaN       NaN       NaN        NaN
# 16         NaN            NaN           NaN       NaN       NaN        NaN
# 17         8.0            NaN           NaN       NaN       NaN        NaN
# 18         NaN            NaN           NaN       NaN       NaN        NaN
# 19         NaN            NaN           NaN       NaN       NaN        NaN
#
#     other_sales release_date ESRB_Rating  Total_Sales
# 0           NaN   2005-03-22           M        35.05
# 1           NaN   2005-03-22           M         4.62
# 2           NaN   2001-10-16           M        22.00
# 3           NaN   2001-10-16           M         2.16
# 4           NaN   2019-10-01           M          NaN
# 5          3.12   2013-09-17           M        20.32
# 6          3.02   2014-11-18           M        19.39
# 7          1.42   2013-09-17           M        15.86
# 8           NaN   2015-04-14           M        12.60
# 9          0.76   2014-11-18           M         8.72
# 10          NaN          NaN           M          NaN
# 11          NaN          NaN           M          NaN
# 12          NaN   1981-10-23           E        20.00
# 13         0.11   1997-09-30           E         4.16
# 14         0.02   1982-01-01           E         2.20
# 15          NaN   1998-08-01           E          NaN
# 16          NaN   1998-01-01           E          NaN
# 17          NaN   2006-07-12           E          NaN
# 18          NaN   1983-01-01           E          NaN
# 19          NaN   1998-01-01           E          NaN

# %%
df_merged = df_merged.sort_values('Total_Sales', ascending=False)
df_merged = df_merged.reset_index(drop=True)

# %%
df_merged.describe()
# Out:
#          vg_score  critic_score  user_score  total_shipped  global_sales  \
# count  853.000000   6492.000000  375.000000    2209.000000  19189.000000
# mean     7.380305      7.212400    8.114933       3.902100      0.362932
# std      1.389045      1.455481    1.594707      15.262025      0.826811
# min      2.600000      1.000000    1.000000       0.030000      0.000000
# 25%      6.700000      6.400000    7.500000       0.190000      0.030000
# 50%      7.700000      7.500000    8.500000       0.690000      0.120000
# 75%      8.400000      8.300000    9.100000       2.200000      0.360000
# max      9.600000     10.000000   10.000000     310.000000     20.320000
#
#            na_sales     jp_sales     pal_sales   other_sales   Total_Sales
# count  12870.000000  6901.000000  13062.000000  15379.000000  21398.000000
# mean       0.273277     0.109332      0.153633      0.044307      0.728295
# std        0.509090     0.182772      0.396473      0.128626      5.080270
# min        0.000000     0.000000      0.000000      0.000000      0.000000
# 25%        0.050000     0.020000      0.010000      0.000000      0.040000
# 50%        0.120000     0.050000      0.040000      0.010000      0.140000
# 75%        0.280000     0.120000      0.140000      0.040000      0.430000
# max        9.760000     2.690000      9.850000      3.120000    310.000000

# %%
df_merged.describe(include=object)
# Out:
#                      title console  genre publisher developer release_date  \
# count                55845   55845  55845     55845     55845        52690
# unique               36808      77     20      3141      8189         7387
# top     Plants vs. Zombies      PC   Misc   Unknown   Unknown   1994-01-01
# freq                    20   10954   9153      4607      4410          507
#
#        ESRB_Rating
# count        24680
# unique           8
# top              E
# freq         11045

# %%
df_merged
# Out:
#                                  title console             genre  \
# 0                     Grand Theft Auto  Series  Action-Adventure
# 1                         Call of Duty  Series           Shooter
# 2                             The Sims  Series        Simulation
# 3                            Minecraft  Series           Sandbox
# 4                               Tetris  Series            Puzzle
# ...                                ...     ...               ...
# 55840          WILL: A Wonderful World      PC      Visual Novel
# 55841                   Without Within      PC      Visual Novel
# 55842                 Without Within 2      PC      Visual Novel
# 55843                 Without Within 3      PC      Visual Novel
# 55844  Yunohana SpRING! ~Mellow Times~      NS      Visual Novel
#
#              publisher                                          developer  \
# 0            ASC Games      Rockstar North|Rockstar Leeds|Digital Eclipse
# 1           Activision  Infinity Ward|Grey Matter Interactive|Treyarch...
# 2      Electronic Arts                                              Maxis
# 3               Mojang                                             Mojang
# 4              Unknown  Alexey Pajitnov|AcademySoft|Andromeda Software...
# ...                ...                                                ...
# 55840      AGM Playism                                      4D Door Games
# 55841      InvertMouse                                        InvertMouse
# 55842      InvertMouse                                        InvertMouse
# 55843      InvertMouse                                        InvertMouse
# 55844     Idea Factory                                            Otomate
#
#        vg_score  critic_score  user_score  total_shipped  global_sales  \
# 0           NaN           NaN         NaN          310.0           NaN
# 1           NaN           NaN         NaN          300.0           NaN
# 2           NaN           NaN         NaN          200.0           NaN
# 3           NaN           NaN         NaN          200.0           NaN
# 4           NaN           NaN         NaN          171.0           NaN
# ...         ...           ...         ...            ...           ...
# 55840       NaN           NaN         NaN            NaN           NaN
# 55841       NaN           NaN         NaN            NaN           NaN
# 55842       NaN           NaN         NaN            NaN           NaN
# 55843       NaN           NaN         NaN            NaN           NaN
# 55844       NaN           NaN         NaN            NaN           NaN
#
#        na_sales  jp_sales  pal_sales  other_sales release_date ESRB_Rating  \
# 0           NaN       NaN        NaN          NaN   1998-03-27           M
# 1           NaN       NaN        NaN          NaN   2003-10-29           T
# 2           NaN       NaN        NaN          NaN   2000-02-04           T
# 3           NaN       NaN        NaN          NaN   2011-11-18         NaN
# 4           NaN       NaN        NaN          NaN   1984-06-06           E
# ...         ...       ...        ...          ...          ...         ...
# 55840       NaN       NaN        NaN          NaN   2017-06-06         NaN
# 55841       NaN       NaN        NaN          NaN   2015-01-22         NaN
# 55842       NaN       NaN        NaN          NaN   2015-11-09         NaN
# 55843       NaN       NaN        NaN          NaN   2018-05-03         NaN
# 55844       NaN       NaN        NaN          NaN   2019-02-28         NaN
#
#        Total_Sales
# 0            310.0
# 1            300.0
# 2            200.0
# 3            200.0
# 4            171.0
# ...            ...
# 55840          NaN
# 55841          NaN
# 55842          NaN
# 55843          NaN
# 55844          NaN
#
# [55845 rows x 17 columns]

# %%
df_merged.to_csv('Adjusted Video Game Sales Database.csv')

# %% [markdown]
# # Consoles

# %%
console_count = df_merged['console'].value_counts().rename_axis('Console Name').reset_index(name = 'counts')
console_count =  console_count.nlargest(10, 'counts')
console_count
# Out:
#   Console Name  counts
# 0           PC   10954
# 1          PS2    3548
# 2           DS    3256
# 3           PS    2690
# 4          XBL    2112
# 5          PSN    1994
# 6          PS3    1857
# 7          PS4    1788
# 8          PSP    1777
# 9         X360    1698

# %%
console_plot = sns.catplot(data = console_count, x='counts', y = 'Console Name', kind='bar', orient='h' )
console_plot.fig.set_size_inches(10.5, 6.5)
console_plot.set_axis_labels("Game Count", "Top 10 Consoles")

# %% [markdown]
# # ESRB Rating

# %% [markdown]
# This section counts how many unique video game titles there are that have the same ESRB

# %%
esrbToCount = df_merged[['title', 'ESRB_Rating']]
esrbToCount = esrbToCount.groupby(["ESRB_Rating"], as_index=False)['title'].nunique()
esrbToCount.rename(columns={'ESRB_Rating': 'ESRB Rating', 'title':'Count'}, inplace=True)

esrbToCount = esrbToCount.sort_values(by="Count", ascending=False)

esrbToCount
# Out:
#   ESRB Rating  Count
# 1           E   6590
# 7           T   3578
# 5           M   1640
# 2         E10   1366
# 6          RP    197
# 3          EC     41
# 0          AO     16
# 4          KA      3

# %%
esrbtoCount_plot =  sns.barplot(data = esrbToCount, x = "ESRB Rating", y = "Count")

# %% [markdown]
# # Genre

# %%
genre_count = df_merged[['title', 'genre']]
genre_count = genre_count.groupby(["genre"], as_index=False)['title'].nunique()
genre_count.rename(columns={'genre': 'Genre', 'title':'Count'}, inplace=True)

genre_count = genre_count.sort_values(by="Count", ascending=False)

genre_count
# Out:
#                Genre  Count
# 7               Misc   6825
# 0             Action   5010
# 2          Adventure   3857
# 13      Role-Playing   3321
# 17            Sports   3103
# 15           Shooter   2917
# 18          Strategy   2618
# 11            Puzzle   2361
# 16        Simulation   2156
# 10          Platform   2003
# 12            Racing   1799
# 5           Fighting   1311
# 1   Action-Adventure    352
# 19      Visual Novel    243
# 8              Music    120
# 9              Party     65
# 6                MMO     45
# 3         Board Game     14
# 4          Education     12
# 14           Sandbox      8

# %%
genre_plot = sns.catplot(data = genre_count, x = 'Count', y = 'Genre', orient='h', kind="bar")

# %% [markdown]
# # ESRB Rating to Total Sales

# %%
esrbToTotal = df_merged[['title', 'ESRB_Rating', 'Total_Sales']]

esrbToTotal
# Out:
#                                  title ESRB_Rating  Total_Sales
# 0                     Grand Theft Auto           M        310.0
# 1                         Call of Duty           T        300.0
# 2                             The Sims           T        200.0
# 3                            Minecraft         NaN        200.0
# 4                               Tetris           E        171.0
# ...                                ...         ...          ...
# 55840          WILL: A Wonderful World         NaN          NaN
# 55841                   Without Within         NaN          NaN
# 55842                 Without Within 2         NaN          NaN
# 55843                 Without Within 3         NaN          NaN
# 55844  Yunohana SpRING! ~Mellow Times~         NaN          NaN
#
# [55845 rows x 3 columns]

# %%
esrbToTotal['Total_Sales'].describe()
# Out:
# count    21398.000000
# mean         0.728295
# std          5.080270
# min          0.000000
# 25%          0.040000
# 50%          0.140000
# 75%          0.430000
# max        310.000000
# Name: Total_Sales, dtype: float64

# %% [markdown]
# ### **Checking sales of AO and KA

# %%
esrbToTotal_a = esrbToTotal[esrbToTotal['ESRB_Rating'].str.contains('AO') == True]

esrbToTotal_a = esrbToTotal_a.groupby(["ESRB_Rating"], as_index=False)["Total_Sales"].sum()

esrbToTotal_a
# Out:
#   ESRB_Rating  Total_Sales
# 0          AO          0.0

# %%
esrbToTotal_b = esrbToTotal[esrbToTotal['ESRB_Rating'].str.contains('KA') == True]

esrbToTotal_b = esrbToTotal_b.groupby(["ESRB_Rating"], as_index=False)["Total_Sales"].sum()

esrbToTotal_b
# Out:
#   ESRB_Rating  Total_Sales
# 0          KA          0.0

# %% [markdown]
# ### Plotting for ESRB to Total Sales

# %%
ESRB_sales_plot = sns.catplot(y = 'Total_Sales', x = 'ESRB_Rating', data=esrbToTotal)
ESRB_sales_plot.set_axis_labels("ESRB Rating", "Total Sales in Millions", labelpad=10)

# %% [markdown]
# # Genre to Total Sales

# %%
df_merged['genre'].describe()
# Out:
# count     55845
# unique       20
# top        Misc
# freq       9153
# Name: genre, dtype: object

# %%
df_merged['genre'].unique()
# Out:
# array(['Action-Adventure', 'Shooter', 'Simulation', 'Sandbox', 'Puzzle',
#        'Role-Playing', 'Sports', 'Racing', 'Platform', 'Music',
#        'Education', 'Fighting', 'Party', 'Strategy', 'Misc', 'Action',
#        'MMO', 'Adventure', 'Visual Novel', 'Board Game'], dtype=object)

# %%
genre_sales =  df_merged.groupby(['genre'], as_index=False)['Total_Sales'].sum()
genre_sales
# Out:
#                genre  Total_Sales
# 0             Action      1625.59
# 1   Action-Adventure      1414.05
# 2          Adventure       531.08
# 3         Board Game         0.33
# 4          Education        65.42
# 5           Fighting       746.69
# 6                MMO        63.90
# 7               Misc       942.03
# 8              Music       205.24
# 9              Party       159.74
# 10          Platform      1337.82
# 11            Puzzle       545.27
# 12            Racing       965.54
# 13      Role-Playing      1459.26
# 14           Sandbox       217.35
# 15           Shooter      2153.19
# 16        Simulation       827.69
# 17            Sports      1900.60
# 18          Strategy       414.23
# 19      Visual Novel         9.03

# %%
total_per_genre = genre_sales['Total_Sales']

# %%
genre_sales_plot = sns.catplot(y = 'genre', x = 'Total_Sales', data=genre_sales, orient='h', kind='bar')
genre_sales_plot.fig.set_size_inches(10.5, 6.5)
genre_sales_plot.set_axis_labels("Total Sales in Millions", "Video Game Genres", labelpad=10)

# %% [markdown]
# # Console To Total Sales

# %%
df_merged['console'].describe()
# Out:
# count     55845
# unique       77
# top          PC
# freq      10954
# Name: console, dtype: object

# %%
df_merged['console'].unique()
# Out:
# array(['Series', 'Wii', 'NES', 'PC', 'DS', 'GB', 'NS', 'X360', 'SNES',
#        'PS3', 'PS4', '3DS', 'PS2', 'GEN', 'N64', 'PS', 'XOne', 'WiiU',
#        'XB', 'PSP', '2600', 'GC', 'GBA', 'GBC', 'PSN', 'PSV', 'DC', 'XBL',
#        'SAT', 'SCD', 'WS', 'Amig', 'VC', 'NG', 'WW', 'PCE', '3DO', 'GG',
#        'OSX', 'Mob', 'PCFX', 'XSX', 'PS5', '5200', 'Int', 'And', 'WinP',
#        'Linux', 'NGage', 'ACPC', 'Arc', 'AST', 'ZXS', 'C64', 'MS', 'S32X',
#        'Lynx', '7800', 'ApII', 'MSX', 'DSiW', 'DSi', 'FMT', 'MSD', 'AJ',
#        'iQue', 'iOS', 'GIZ', 'BRW', 'VB', 'Ouya', 'TG16', 'C128', 'CDi',
#        'CD32', 'BBCM', 'Aco'], dtype=object)

# %%
console_sales =  df_merged.groupby(['console'], as_index=False)['Total_Sales'].sum()
console_sales = console_sales.sort_values(ascending=False, by=['Total_Sales'])
console_sales[0:10]
# Out:
#    console  Total_Sales
# 60  Series      5113.47
# 49     PS2      1255.53
# 45      PC      1180.15
# 69    X360       983.18
# 50     PS3       965.74
# 66     Wii       894.43
# 20      DS       741.34
# 48      PS       728.32
# 51     PS4       692.25
# 72    XOne       298.87

# %%
console_sales_plot = sns.catplot(y = 'console', x = 'Total_Sales', data=console_sales[0:10], orient='h', kind='bar')
console_sales_plot.fig.set_size_inches(10.5, 6.5)
console_sales_plot.set_axis_labels("Total Sales in Millions", "Top 10 Game Console", labelpad=10)

# %% [markdown]
# # Title to Total Sales

# %%
title_total = df_merged[['title', 'Total_Sales', 'console']]

title_total
# Out:
#                                  title  Total_Sales console
# 0                     Grand Theft Auto        310.0  Series
# 1                         Call of Duty        300.0  Series
# 2                             The Sims        200.0  Series
# 3                            Minecraft        200.0  Series
# 4                               Tetris        171.0  Series
# ...                                ...          ...     ...
# 55840          WILL: A Wonderful World          NaN      PC
# 55841                   Without Within          NaN      PC
# 55842                 Without Within 2          NaN      PC
# 55843                 Without Within 3          NaN      PC
# 55844  Yunohana SpRING! ~Mellow Times~          NaN      NS
#
# [55845 rows x 3 columns]

# %%
title_total_sum = title_total.groupby(["title", 'console'], as_index=False)['Total_Sales'].sum()
title_total_sum = title_total_sum.sort_values(by='Total_Sales', ascending=False)
title_total_sum = title_total_sum.nlargest(20, 'Total_Sales')
title_total_sum
# Out:
#                       title console  Total_Sales
# 19158      Grand Theft Auto  Series       310.00
# 7367           Call of Duty  Series       300.00
# 29126             Minecraft  Series       200.00
# 48607              The Sims  Series       200.00
# 46721                Tetris  Series       171.00
# 16389         Final Fantasy  Series       152.50
# 3286       Assassin's Creed  Series       140.00
# 53300            Wii Sports  Series       115.99
# 48010   The Legend of Zelda  Series       107.07
# 35891  Pro Evolution Soccer  Series       106.80
# 30798                NBA 2K  Series       102.00
# 37811         Resident Evil  Series       100.00
# 53301            Wii Sports     Wii        82.90
# 19110          Gran Turismo  Series        80.40
# 42634    Sonic the Hedgehog  Series        76.64
# 49917           Tomb Raider  Series        75.00
# 23517            Just Dance  Series        70.00
# 9639         Counter-Strike  Series        65.00
# 48312      The Oregon Trail  Series        65.00
# 29648        Monster Hunter  Series        63.00

# %%
title_total_plot = sns.catplot(data = title_total_sum, x = "Total_Sales", y = "title", kind="bar", orient = 'h')
title_total_plot.fig.set_size_inches(10.5, 6.5)
title_total_plot.set_axis_labels("Total Sales in Millions", "Top 20 Game Titles", labelpad=10)

# %% [markdown]
# # Top 10 Games Per Region

# %%
region_sales = df_merged[['title', 'na_sales','jp_sales','pal_sales','other_sales']]

region_sales
# Out:
#                                  title  na_sales  jp_sales  pal_sales  \
# 0                     Grand Theft Auto       NaN       NaN        NaN
# 1                         Call of Duty       NaN       NaN        NaN
# 2                             The Sims       NaN       NaN        NaN
# 3                            Minecraft       NaN       NaN        NaN
# 4                               Tetris       NaN       NaN        NaN
# ...                                ...       ...       ...        ...
# 55840          WILL: A Wonderful World       NaN       NaN        NaN
# 55841                   Without Within       NaN       NaN        NaN
# 55842                 Without Within 2       NaN       NaN        NaN
# 55843                 Without Within 3       NaN       NaN        NaN
# 55844  Yunohana SpRING! ~Mellow Times~       NaN       NaN        NaN
#
#        other_sales
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 55840          NaN
# 55841          NaN
# 55842          NaN
# 55843          NaN
# 55844          NaN
#
# [55845 rows x 5 columns]

# %%
region_sales_na = region_sales.groupby(["title"], as_index=False)['na_sales'].sum()
region_sales_na = region_sales_na.sort_values(by='na_sales', ascending=False)
region_sales_na = region_sales_na.nlargest(20, 'na_sales')
region_sales_na
# Out:
#                                    title  na_sales
# 12707                 Grand Theft Auto V     26.19
# 4863             Call of Duty: Black Ops     17.65
# 4875      Call of Duty: Modern Warfare 3     15.57
# 4872                Call of Duty: Ghosts     15.06
# 4869          Call of Duty: Black Ops II     14.12
# 4874      Call of Duty: Modern Warfare 2     13.54
# 4868           Call of Duty: Black Ops 3     12.82
# 12702                Grand Theft Auto IV     11.60
# 12962   Guitar Hero III: Legends of Rock     11.14
# 4862      Call of Duty: Advanced Warfare     10.66
# 4859      Call of Duty 4: Modern Warfare     10.06
# 31535        The Elder Scrolls V: Skyrim      9.52
# 4886          Call of Duty: World at War      9.38
# 19514                          Minecraft      9.07
# 25048              Red Dead Redemption 2      9.02
# 17001  LEGO Star Wars: The Complete Saga      8.95
# 18022                      Madden NFL 07      8.67
# 4885                  Call of Duty: WWII      8.49
# 12717        Grand Theft Auto: Vice City      8.41
# 3212                       Battlefield 3      8.22

# %%
region_sales_na_plot = sns.catplot(data = region_sales_na, x = "na_sales", y = "title", kind="bar", orient = 'h')
region_sales_na_plot.fig.set_size_inches(10.5, 6.5)
region_sales_na_plot.set_axis_labels("Total Sales in Millions", "Top 20 Game Titles in North America", labelpad=10)

# %%
region_sales_jp = region_sales.groupby(["title"], as_index=False)['jp_sales'].sum()
region_sales_jp = region_sales_jp.sort_values(by='jp_sales', ascending=False)
region_sales_jp = region_sales_jp.nlargest(20, 'jp_sales')
region_sales_jp
# Out:
#                                                    title  jp_sales
# 14287                                     Hot Shots Golf      4.26
# 36109                    Yokai Watch 2: Psychic Specters      2.69
# 19514                                          Minecraft      2.50
# 36279                          Yu-Gi-Oh: Duel Monsters 4      2.17
# 24522                                    R.B.I. Baseball      2.05
# 7725                                      Derby Stallion      2.05
# 10474                        Famista '89 - Kaimaku Han!!      2.05
# 10848                                 Final Fantasy XIII      1.88
# 8878                                     Dragon Quest XI      1.82
# 30103                                    Super Puyo Puyo      1.69
# 33059                     Tomodachi Collection: New Life      1.69
# 12707                                 Grand Theft Auto V      1.66
# 36239                            Yu-Gi-Oh! Duel Monsters      1.61
# 8873                                      Dragon Quest X      1.56
# 21583  Ninja Hattori Kun: Ninja wa Shuugyou Degogiru ...      1.50
# 14288                                   Hot Shots Golf 2      1.48
# 22511                                 PaRappa The Rapper      1.48
# 8737                                       Dragon Ball Z      1.45
# 11940                      Game de Hakken!! Tamagotchi 2      1.44
# 30796                                         Tamagotchi      1.44

# %%
region_sales_jp_plot = sns.catplot(data = region_sales_jp, x = "jp_sales", y = "title", kind="bar", orient = 'h')
region_sales_jp_plot.fig.set_size_inches(20.5, 6.5)
region_sales_jp_plot.set_axis_labels("Total Sales in Millions", "Top 20 Game Titles in Japan", labelpad=10)

# %%
region_sales_pal = region_sales.groupby(["title"], as_index=False)['pal_sales'].sum()
region_sales_pal = region_sales_pal.sort_values(by='pal_sales', ascending=False)
region_sales_pal = region_sales_pal.nlargest(20, 'pal_sales')
region_sales_pal
# Out:
#                                 title  pal_sales
# 12707              Grand Theft Auto V      28.14
# 10210                         FIFA 15      12.45
# 10209                         FIFA 14      12.14
# 10213                         FIFA 17      12.07
# 10214                         FIFA 18      11.78
# 4875   Call of Duty: Modern Warfare 3      11.26
# 4869       Call of Duty: Black Ops II      11.08
# 10212                         FIFA 16      10.56
# 10208                         FIFA 13      10.11
# 4868        Call of Duty: Black Ops 3       9.76
# 4872             Call of Duty: Ghosts       9.60
# 32311                      The Sims 3       9.55
# 19514                       Minecraft       9.48
# 4863          Call of Duty: Black Ops       9.45
# 10215                         FIFA 19       8.93
# 10242                  FIFA Soccer 12       8.51
# 4885               Call of Duty: WWII       8.23
# 4874   Call of Duty: Modern Warfare 2       8.08
# 31535     The Elder Scrolls V: Skyrim       8.08
# 10240                  FIFA Soccer 11       7.99

# %%
region_sales_pal_plot = sns.catplot(data = region_sales_pal, x = "pal_sales", y = "title", kind="bar", orient = 'h')
region_sales_pal_plot.fig.set_size_inches(10.5, 6.5)
region_sales_pal_plot.set_axis_labels("Total Sales in Millions", "Top 20 Game Titles in the PAL region", labelpad=10)

# %%
region_sales_other = region_sales.groupby(["title"], as_index=False)['other_sales'].sum()
region_sales_other = region_sales_other.sort_values(by='other_sales', ascending=False)
region_sales_other = region_sales_other.nlargest(20, 'other_sales')
region_sales_other
# Out:
#                                   title  other_sales
# 12707                Grand Theft Auto V         8.32
# 4869         Call of Duty: Black Ops II         3.67
# 4872               Call of Duty: Ghosts         3.65
# 4868          Call of Duty: Black Ops 3         3.63
# 10233                    FIFA Soccer 08         3.53
# 23978         Pro Evolution Soccer 2008         3.51
# 4863            Call of Duty: Black Ops         3.31
# 4875     Call of Duty: Modern Warfare 3         3.26
# 19514                         Minecraft         2.96
# 4874     Call of Duty: Modern Warfare 2         2.95
# 10234                    FIFA Soccer 09         2.86
# 4862     Call of Duty: Advanced Warfare         2.81
# 25048             Red Dead Redemption 2         2.80
# 12702               Grand Theft Auto IV         2.72
# 4885                 Call of Duty: WWII         2.70
# 12962  Guitar Hero III: Legends of Rock         2.64
# 22481    PES 2009: Pro Evolution Soccer         2.62
# 21238         Need for Speed: ProStreet         2.57
# 31535       The Elder Scrolls V: Skyrim         2.50
# 10237                    FIFA Soccer 10         2.48

# %%
region_sales_other_plot = sns.catplot(data = region_sales_other, x = "other_sales", y = "title", kind="bar", orient = 'h')
region_sales_other_plot.fig.set_size_inches(10.5, 6.5)
region_sales_other_plot.set_axis_labels("Total Sales in Millions", "Top 20 Game Titles in Other regions", labelpad=10)

# %% [markdown]
# # Critic Score and User Score Relationship

# %%
crit_user_score = df_merged[['title', 'Total_Sales','critic_score','user_score' ]]

crit_user_score
# Out:
#                                  title  Total_Sales  critic_score  user_score
# 0                     Grand Theft Auto        310.0           NaN         NaN
# 1                         Call of Duty        300.0           NaN         NaN
# 2                             The Sims        200.0           NaN         NaN
# 3                            Minecraft        200.0           NaN         NaN
# 4                               Tetris        171.0           NaN         NaN
# ...                                ...          ...           ...         ...
# 55840          WILL: A Wonderful World          NaN           NaN         NaN
# 55841                   Without Within          NaN           NaN         NaN
# 55842                 Without Within 2          NaN           NaN         NaN
# 55843                 Without Within 3          NaN           NaN         NaN
# 55844  Yunohana SpRING! ~Mellow Times~          NaN           NaN         NaN
#
# [55845 rows x 4 columns]

# %%
crit_user_score = crit_user_score.dropna(how='any',axis=0) 

crit_user_score[0:50]
# Out:
#                                         title  Total_Sales  critic_score  \
# 37                          Super Mario Bros.        40.24          10.0
# 41                             Mario Kart Wii        37.32           8.2
# 48                          Wii Sports Resort        33.13           8.0
# 51                      New Super Mario Bros.        30.80           9.1
# 52                  New Super Mario Bros. Wii        30.30           8.6
# 60                                   Wii Play        28.02           5.9
# 71                              Mario Kart DS        23.60           9.1
# 93                 Super Smash Bros. Ultimate        18.84           9.4
# 99    The Legend of Zelda: Breath of the Wild        17.41           9.9
# 125                                    Halo 3        14.50           9.6
# 131            Call of Duty: Modern Warfare 2        13.53           9.5
# 136                   Super Smash Bros. Brawl        13.32           9.2
# 144                        Super Mario Galaxy        12.80           9.7
# 155                         World of Warcraft        12.00           9.2
# 170                         God of War (2018)        11.00           9.7
# 176                       Grand Theft Auto IV        10.57          10.0
# 186                        Horizon: Zero Dawn        10.00           9.1
# 198                         Final Fantasy VII         9.90           9.6
# 205            Call of Duty 4: Modern Warfare         9.41           9.6
# 211            Uncharted 3: Drake's Deception         9.30           9.3
# 219                        Grand Theft Auto V         8.72           9.0
# 221                           Final Fantasy X         8.60           9.0
# 240                            God of War III         7.60           9.2
# 241      The Legend of Zelda: Ocarina of Time         7.60           9.9
# 244                Call of Duty: World at War         7.50           8.5
# 248                      Super Mario Galaxy 2         7.41           9.7
# 253    The Legend of Zelda: Twilight Princess         7.26           9.5
# 267                Uncharted 2: Among Thieves         6.74           9.5
# 268            Call of Duty 4: Modern Warfare         6.72           9.5
# 279                       Red Dead Redemption         6.50           9.5
# 284                         Final Fantasy XII         6.40           9.4
# 297       Metal Gear Solid 2: Sons of Liberty         6.05           9.5
# 299  Metal Gear Solid 4: Guns of the Patriots         6.00           9.3
# 325                          Assassin's Creed         5.55           8.2
# 329                        Forza Motorsport 3         5.50           9.2
# 341                        Final Fantasy XIII         5.35           8.0
# 367                           Resident Evil 5         5.10           8.6
# 372                          Final Fantasy XV         5.07           8.1
# 378                            Gears of War 2         5.00           9.4
# 379                              Gears of War         5.00           9.4
# 387                Uncharted: Drake's Fortune         4.97           8.7
# 389                                 Fallout 3         4.96           9.0
# 400                          Assassin's Creed         4.83           8.2
# 411                              Gran Turismo         4.67           7.7
# 416                               Left 4 Dead         4.60           8.6
# 433                           LittleBigPlanet         4.50           9.4
# 448                   Resistance: Fall of Man         4.37           8.5
# 454                Animal Crossing: City Folk         4.32           7.1
# 458                          Dragon Quest VII         4.30           8.0
# 463                             God of War II         4.24           9.3
#
#      user_score
# 37          8.2
# 41          9.1
# 48          8.8
# 51          8.1
# 52          9.2
# 60          4.5
# 71          9.4
# 93          9.7
# 99         10.0
# 125         9.5
# 131         9.0
# 136         9.7
# 144         9.6
# 155         8.0
# 170        10.0
# 176         9.0
# 186         8.0
# 198         9.5
# 205         9.0
# 211         6.3
# 219         9.0
# 221        10.0
# 240         9.4
# 241        10.0
# 244         7.8
# 248         9.8
# 253         9.6
# 267         9.6
# 268         9.6
# 279        10.0
# 284         9.5
# 297         7.0
# 299         9.8
# 325         8.0
# 329         9.8
# 341         9.2
# 367         8.8
# 372         9.5
# 378         9.5
# 379         9.4
# 387         8.6
# 389         8.6
# 400         8.5
# 411         9.5
# 416         8.5
# 433         9.2
# 448         9.1
# 454         8.8
# 458         3.0
# 463         9.8

# %%
crit_user_score.describe()
# Out:
#        Total_Sales  critic_score  user_score
# count   221.000000    221.000000  221.000000
# mean      3.483937      8.145249    8.553394
# std       6.140744      1.185111    1.121991
# min       0.000000      3.500000    3.000000
# 25%       0.550000      7.500000    8.000000
# 50%       1.330000      8.200000    8.800000
# 75%       3.640000      9.100000    9.300000
# max      40.240000     10.000000   10.000000

# %% [markdown]
# ### Publishers to Most Sales

# %%
publisherSales = df_merged[['publisher','Total_Sales']].copy()
publisherSales
# Out:
#              publisher  Total_Sales
# 0            ASC Games        310.0
# 1           Activision        300.0
# 2      Electronic Arts        200.0
# 3               Mojang        200.0
# 4              Unknown        171.0
# ...                ...          ...
# 55840      AGM Playism          NaN
# 55841      InvertMouse          NaN
# 55842      InvertMouse          NaN
# 55843      InvertMouse          NaN
# 55844     Idea Factory          NaN
#
# [55845 rows x 2 columns]

# %%
publisherSales = publisherSales.groupby(["publisher"], as_index=False)['Total_Sales'].sum()
publisherSales = publisherSales.sort_values(by='Total_Sales', ascending=False)
publisherSales = publisherSales.nlargest(20, 'Total_Sales')
publisherSales
# Out:
#                         publisher  Total_Sales
# 1882                     Nintendo      2428.18
# 93                     Activision      1080.04
# 790               Electronic Arts       966.40
# 2825                      Ubisoft       892.95
# 2490  Sony Computer Entertainment       792.68
# 446                        Capcom       574.61
# 2363                         Sega       530.63
# 753                     EA Sports       522.04
# 1461                       Konami       498.89
# 2841                      Unknown       491.07
# 2619                          THQ       388.78
# 69                      ASC Games       312.36
# 2274               Rockstar Games       273.85
# 1756                       Mojang       240.66
# 2529                       Square       236.52
# 781             Eidos Interactive       212.91
# 2531                  Square Enix       207.40
# 1818                        Namco       200.18
# 1699       Microsoft Game Studios       195.10
# 240                         Atari       192.27

# %%
publisherSalesPlot = sns.catplot(data = publisherSales, x = "Total_Sales", y = "publisher", kind="bar", orient = 'h')
publisherSalesPlot.fig.set_size_inches(10.5, 6.5)
publisherSalesPlot.set_axis_labels("Total Sales in Millions", "Top 20 Publishers With The Most Sales", labelpad=10)

# %% [markdown]
# ### Trend of New Video Games

# %%
trendGames = df_merged
trendGames['release_date'] = pd.to_datetime(trendGames['release_date'], format='%Y-%m-%d')
trendGames = trendGames.loc[trendGames['release_date'].dt.year > 2018]
trendGames
# Out:
#                                        title console             genre  \
# 273           New Super Mario Bros. U Deluxe      NS          Platform
# 286                        Luigi's Mansion 3      NS  Action-Adventure
# 334                      Super Mario Maker 2      NS          Platform
# 446    The Legend of Zelda: Link's Awakening      NS  Action-Adventure
# 507                  The Last of Us: Part II     PS4            Action
# ...                                      ...     ...               ...
# 55836       Tlicolity Eyes: Twinkle Snowtime      NS      Visual Novel
# 55837                     Variable Barricade     PSV      Visual Novel
# 55838                WILL: A Wonderful World     PS4      Visual Novel
# 55839                WILL: A Wonderful World      NS      Visual Novel
# 55844        Yunohana SpRING! ~Mellow Times~      NS      Visual Novel
#
#                             publisher               developer  vg_score  \
# 273                          Nintendo            Nintendo EPD       NaN
# 286                          Nintendo  Next Level Games, Inc.       6.0
# 334                          Nintendo                Nintendo       NaN
# 446                          Nintendo                Nintendo       8.0
# 507    Sony Interactive Entertainment             Naughty Dog       NaN
# ...                               ...                     ...       ...
# 55836                    Idea Factory            Idea Factory       NaN
# 55837                    Idea Factory                 Otomate       NaN
# 55838                      PM Studios           4D Door Games       NaN
# 55839                      PM Studios           4D Door Games       NaN
# 55844                    Idea Factory                 Otomate       NaN
#
#        critic_score  user_score  total_shipped  global_sales  na_sales  \
# 273             NaN         6.6           6.60           NaN       NaN
# 286             NaN         NaN           6.33           NaN       NaN
# 334             NaN         NaN           5.48           NaN       NaN
# 446             NaN         NaN           4.38           NaN       NaN
# 507             NaN         NaN           4.00           NaN       NaN
# ...             ...         ...            ...           ...       ...
# 55836           NaN         NaN            NaN           NaN       NaN
# 55837           NaN         NaN            NaN           NaN       NaN
# 55838           NaN         NaN            NaN           NaN       NaN
# 55839           NaN         NaN            NaN           NaN       NaN
# 55844           NaN         NaN            NaN           NaN       NaN
#
#        jp_sales  pal_sales  other_sales release_date ESRB_Rating  Total_Sales
# 273         NaN        NaN          NaN   2019-01-11           E         6.60
# 286         NaN        NaN          NaN   2019-10-31         NaN         6.33
# 334         NaN        NaN          NaN   2019-06-28          RP         5.48
# 446         NaN        NaN          NaN   2019-09-20           E         4.38
# 507         NaN        NaN          NaN   2020-06-19         NaN         4.00
# ...         ...        ...          ...          ...         ...          ...
# 55836       NaN        NaN          NaN   2019-07-18         NaN          NaN
# 55837       NaN        NaN          NaN   2019-04-04         NaN          NaN
# 55838       NaN        NaN          NaN   2019-03-26         NaN          NaN
# 55839       NaN        NaN          NaN   2019-03-26         NaN          NaN
# 55844       NaN        NaN          NaN   2019-02-28         NaN          NaN
#
# [897 rows x 17 columns]

# %%
trendGames = trendGames.sort_values(by='Total_Sales', ascending=False)
trendGames = trendGames.nlargest(20, 'Total_Sales')
trendGames
# Out:
#                                             title console             genre  \
# 273                New Super Mario Bros. U Deluxe      NS          Platform
# 286                             Luigi's Mansion 3      NS  Action-Adventure
# 334                           Super Mario Maker 2      NS          Platform
# 446         The Legend of Zelda: Link's Awakening      NS  Action-Adventure
# 507                       The Last of Us: Part II     PS4            Action
# 591                      Final Fantasy VII Remake     PS4      Role-Playing
# 705                               Space Engineers      PC        Simulation
# 757                     Fire Emblem: Three Houses      NS      Role-Playing
# 890                              The Outer Worlds  Series      Role-Playing
# 2259                               Slay the Spire      PC          Strategy
# 2291                        Yoshi's Crafted World      NS          Platform
# 2367  Marvel Ultimate Alliance 3: The Black Order      NS            Action
# 2368                                 Astral Chain      NS            Action
# 2602                    Total War: Three Kingdoms      PC          Strategy
# 2617                                    Code Vein  Series      Role-Playing
# 2587                            My Time At Portia      PC        Simulation
# 2561                                       Nioh 2     PS4            Action
# 2862                               Fitness Boxing      NS             Music
# 3111                      Yokai Watch 3: Sukiyaki     3DS      Role-Playing
# 6014                                Shovel Knight      NS          Platform
#
#                            publisher               developer  vg_score  \
# 273                         Nintendo            Nintendo EPD       NaN
# 286                         Nintendo  Next Level Games, Inc.       6.0
# 334                         Nintendo                Nintendo       NaN
# 446                         Nintendo                Nintendo       8.0
# 507   Sony Interactive Entertainment             Naughty Dog       NaN
# 591                      Square Enix             Square Enix       9.0
# 705              Keen Software House     Keen Software House       NaN
# 757                         Nintendo     Intelligent Systems       8.0
# 890                 Private Division  Obsidian Entertainment       NaN
# 2259                 Mega Crit Games         Mega Crit Games       NaN
# 2291                        Nintendo               Good-Feel       8.0
# 2367                        Nintendo              Team Ninja       NaN
# 2368                        Nintendo           PlatinumGames       NaN
# 2602                            Sega       Creative Assembly       NaN
# 2617      Bandai Namco Entertainment    Bandai Namco Studios       NaN
# 2587              Team17 Digital Ltd            Pathea Games       NaN
# 2561  Sony Interactive Entertainment              Team Ninja       NaN
# 2862                        Nintendo               Imagineer       NaN
# 3111                        Nintendo                 Level 5       NaN
# 6014                Yacht Club Games        Yacht Club Games       NaN
#
#       critic_score  user_score  total_shipped  global_sales  na_sales  \
# 273            NaN         6.6           6.60           NaN       NaN
# 286            NaN         NaN           6.33           NaN       NaN
# 334            NaN         NaN           5.48           NaN       NaN
# 446            NaN         NaN           4.38           NaN       NaN
# 507            NaN         NaN           4.00           NaN       NaN
# 591            NaN         NaN           3.50           NaN       NaN
# 705            NaN         NaN           3.00           NaN       NaN
# 757            NaN        10.0           2.87           NaN       NaN
# 890            NaN         NaN           2.50           NaN       NaN
# 2259           NaN         NaN           1.12           NaN       NaN
# 2291           7.8         NaN           1.11           NaN       NaN
# 2367           NaN         NaN           1.08           NaN       NaN
# 2368           NaN         NaN           1.08           NaN       NaN
# 2602           8.6         NaN           1.00           NaN       NaN
# 2617           NaN         NaN           1.00           NaN       NaN
# 2587           NaN         NaN           1.00           NaN       NaN
# 2561           NaN         NaN           1.00           NaN       NaN
# 2862           7.0         NaN           0.90           NaN       NaN
# 3111           NaN         NaN            NaN          0.81       NaN
# 6014           9.0         NaN           0.37           NaN       NaN
#
#       jp_sales  pal_sales  other_sales release_date ESRB_Rating  Total_Sales
# 273        NaN        NaN          NaN   2019-01-11           E         6.60
# 286        NaN        NaN          NaN   2019-10-31         NaN         6.33
# 334        NaN        NaN          NaN   2019-06-28          RP         5.48
# 446        NaN        NaN          NaN   2019-09-20           E         4.38
# 507        NaN        NaN          NaN   2020-06-19         NaN         4.00
# 591        NaN        NaN          NaN   2020-04-10         NaN         3.50
# 705        NaN        NaN          NaN   2019-02-28         NaN         3.00
# 757        NaN        NaN          NaN   2019-07-26          RP         2.87
# 890        NaN        NaN          NaN   2019-10-25         NaN         2.50
# 2259       NaN        NaN          NaN   2019-01-23         NaN         1.12
# 2291       NaN        NaN          NaN   2019-03-29           E         1.11
# 2367       NaN        NaN          NaN   2019-07-19          RP         1.08
# 2368       NaN        NaN          NaN   2019-08-30          RP         1.08
# 2602       NaN        NaN          NaN   2019-05-23         NaN         1.00
# 2617       NaN        NaN          NaN   2019-09-27         NaN         1.00
# 2587       NaN        NaN          NaN   2019-01-15         NaN         1.00
# 2561       NaN        NaN          NaN   2020-03-13         NaN         1.00
# 2862       NaN        NaN          NaN   2019-01-04           T         0.90
# 3111      0.81        NaN          NaN   2019-02-02         NaN         0.81
# 6014       NaN        NaN          NaN   2019-04-09         NaN         0.37

# %%
trendPublisher = trendGames.groupby(["publisher"], as_index=False)['Total_Sales'].sum()
trendPublisher = trendPublisher.sort_values(by='Total_Sales', ascending=False)
trendPublisher = trendPublisher.nlargest(20, 'Total_Sales')
trendPublisher
# Out:
#                         publisher  Total_Sales
# 3                        Nintendo        30.64
# 6  Sony Interactive Entertainment         5.00
# 7                     Square Enix         3.50
# 1             Keen Software House         3.00
# 4                Private Division         2.50
# 2                 Mega Crit Games         1.12
# 0      Bandai Namco Entertainment         1.00
# 5                            Sega         1.00
# 8              Team17 Digital Ltd         1.00
# 9                Yacht Club Games         0.37

# %%
trendConsole = trendGames.groupby(["console"], as_index=False)['Total_Sales'].sum()
trendConsole = trendConsole.sort_values(by='Total_Sales', ascending=False)
trendConsole = trendConsole.nlargest(20, 'Total_Sales')
trendConsole
# Out:
#   console  Total_Sales
# 1      NS        30.20
# 3     PS4         8.50
# 2      PC         6.12
# 4  Series         3.50
# 0     3DS         0.81

# %%
trendGenre = trendGames.groupby(["genre"], as_index=False)['Total_Sales'].sum()
trendGenre = trendGenre.sort_values(by='Total_Sales', ascending=False)
trendGenre = trendGenre.nlargest(20, 'Total_Sales')
trendGenre
# Out:
#               genre  Total_Sales
# 3          Platform        13.56
# 1  Action-Adventure        10.71
# 4      Role-Playing        10.68
# 0            Action         7.16
# 5        Simulation         4.00
# 6          Strategy         2.12
# 2             Music         0.90
